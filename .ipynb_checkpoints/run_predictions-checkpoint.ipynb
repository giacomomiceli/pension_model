# %% [markdown]
# # Make prediction

# %%
import sys
import os

project_root = os.path.abspath("../")  # one level up from notebook/

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from pension_model.revamp_predictor import TimeSeriesPredictor

import pandas as pd

# %%
# Create a new predictor instance
new_predictor = TimeSeriesPredictor()

# Load the saved model
success = new_predictor.load_model("models/production_model_v2")
if success:
    print("Model loaded successfully!")
    
    # Check what data is needed for predictions
    requirements = new_predictor.get_prediction_requirements()
    print(" Prediction requirements:", requirements)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 new_predictor = TimeSeriesPredictor()
#       4 # Load the saved model
# ----> 5 success = new_predictor.load_model("models/production_model_v2")
#       6 if success:
#       7     print("Model loaded successfully!")
#
# File ~\Documents\VS_code\pension_model\pension_model\revamp_predictor.py:611, in TimeSeriesPredictor.load_model(self, model_path)
#     608 model_path = Path(model_path)
#     610 if not model_path.exists():
# --> 611     raise FileNotFoundError(f" Model path does not exist: {model_path}")
#     613 try:
#     614     # Load the model
#     615     model_file = model_path / "model.pkl"
#
# FileNotFoundError:  Model path does not exist: models\production_model_v2
