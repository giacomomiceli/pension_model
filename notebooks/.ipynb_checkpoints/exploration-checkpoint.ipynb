# %% [markdown]
# # Pension model - Data exploration

# %% [markdown]
# 1. Data Import & Preliminary Analysis
#
# 2. Exploratory Data Analysis (EDA) & Relationship Checks
#
# 3. Feature Engineering & Preprocessing
#
# 4. Model Selection & Baseline Modeling (GLR, others)
#
# 5. Model Diagnostics & Convergence Monitoring
#
# 6. Overfitting Avoidance & Regularization
#
# 7. Model Evaluation & Testing

# %% [markdown]
# ---

# %%
# !which python
# Out:
# /c/Users/giami/AppData/Local/pypoetry/Cache/virtualenvs/pension-model-iUuso5uW-py3.12/Scripts/python

# %%
import numpy as np
import pandas as pd
import missingno as msno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import missingno as msno
#
# ModuleNotFoundError: No module named 'missingno'

# %% [markdown]
# ## Data importing

# %%
dtypes = {
    "Annee": "int64",
    "D_PIB": "float64"
}

raw_df = pd.read_csv("../data/dataset_COR_norm.csv", index_col=False, dtype=dtypes)
raw_df = raw_df.loc[:, ~raw_df.columns.str.contains("^Unnamed")]

# %%
raw_df.head()
# Out:
#    Annee     D_PIB     PROD    CHO      MI    FEC  ESP_F  ESP_H   PIB_VAL  \
# 0   2002  0.117761  0.02786  0.079   97000  1.881   21.4   17.1  1578.330
# 1   2003  0.118774  0.00614  0.085  102000  1.891   21.3   17.1  1622.313
# 2   2004  0.119571  0.01315  0.089  105128  1.915   22.1   17.7  1696.108
# 3   2005  0.121331  0.00955  0.089   92192  1.938   22.0   17.7  1762.048
# 4   2006  0.121535  0.02648  0.088  112141  1.997   22.4   18.0  1846.021
#
#    PRELEV_REF  CONTRIB_REF   PIB_VOL
# 0        26.9          2.0  2003.664
# 1        27.6          2.0  2023.056
# 2        27.9          2.0  2081.082
# 3        27.9          2.0  2120.384
# 4        28.0          2.1  2177.933

# %% [markdown]
# ## Retail real data, i.e., data related only to past periods

# %%
df = raw_df[raw_df['Annee'] < 2025]

# %%
df.describe()
# Out:
#              Annee       D_PIB        PROD         CHO             MI  \
# count   184.000000  184.000000  184.000000  184.000000     184.000000
# mean   2013.000000    0.132703    0.006166    0.087687  103238.565217
# std       6.651349    0.008383    0.010698    0.009676   58079.945150
# min    2002.000000    0.117761   -0.016730    0.073000   20000.000000
# 25%    2007.000000    0.123052   -0.002460    0.079000   56812.000000
# 50%    2013.000000    0.135912    0.005990    0.089000   97000.000000
# 75%    2019.000000    0.138792    0.013150    0.094000  154661.000000
# max    2024.000000    0.146832    0.027860    0.103000  223005.000000
#
#               FEC       ESP_F       ESP_H      PIB_VAL  PRELEV_REF  \
# count  184.000000  184.000000  184.000000   184.000000  184.000000
# mean     1.915957   22.784613   18.719913  2153.770391   30.047826
# std      0.088901    0.618103    0.793594   351.788237    1.742273
# min      1.676000   21.300000   17.100000  1578.330000   26.900000
# 25%      1.863000   22.500000   18.100000  1935.840000   28.300000
# 50%      1.924000   23.000000   18.900000  2120.352000   31.000000
# 75%      1.999000   23.200000   19.300000  2355.363000   31.700000
# max      2.029000   24.216170   20.421930  2927.453000   32.200000
#
#        CONTRIB_REF      PIB_VOL
# count   184.000000   184.000000
# mean      2.021739  2305.718174
# std       0.065830   164.323156
# min       1.900000  2003.664000
# 25%       2.000000  2178.221000
# 50%       2.000000  2297.960000
# 75%       2.100000  2454.866000
# max       2.100000  2588.508000

# %% [markdown]
# ## Missing data analysis

# %%
msno.matrix(df)
msno.heatmap(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 msno.matrix(df)
#       2 msno.heatmap(df)
#
# NameError: name 'msno' is not defined
