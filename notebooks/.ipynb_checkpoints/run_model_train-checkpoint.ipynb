# %% [markdown]
# # Pension model

# %%
import sys
import os
import pandas as pd
project_root = os.path.abspath("../")  # one level up from notebook/
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from pension_model.predictor import TimeSeriesPredictor

# %% [markdown]
# ## Import raw data

# %%
dtypes = {
    "Annee": "int64",
    "D_PIB": "float64"
}

raw_df = pd.read_csv("../data/dataset_COR_norm.csv", index_col=False, dtype=dtypes)
raw_df = raw_df.loc[:, ~raw_df.columns.str.contains("^Unnamed")]

# %% [markdown]
# ## Historical data and projected/scenario data

# %%
# Check if the length is a multiple of 69
n_years = 69
assert len(raw_df) % n_years == 0, "Data length must be a multiple of 69"

# Create dictionary of DataFrames
grouped_dfs = {
    f"group_{i}": raw_df.iloc[i*n_years:(i+1)*n_years].reset_index(drop=True)
    for i in range(len(raw_df) // n_years)
}

# Show the first group
print(grouped_dfs["group_0"])
# Out:
#     Annee     D_PIB     PROD    CHO      MI    FEC     ESP_F     ESP_H  \
# 0    2002  0.117761  0.02786  0.079   97000  1.881  21.40000  17.10000
# 1    2003  0.118774  0.00614  0.085  102000  1.891  21.30000  17.10000
# 2    2004  0.119571  0.01315  0.089  105128  1.915  22.10000  17.70000
# 3    2005  0.121331  0.00955  0.089   92192  1.938  22.00000  17.70000
# 4    2006  0.121535  0.02648  0.088  112141  1.997  22.40000  18.00000
# ..    ...       ...      ...    ...     ...    ...       ...       ...
# 64   2066  0.131398  0.01000  0.050   70000  1.800  26.41802  24.36323
# 65   2067  0.131499  0.01000  0.050   70000  1.800  26.49499  24.46490
# 66   2068  0.131601  0.01000  0.050   70000  1.800  26.57171  24.56578
# 67   2069  0.131750  0.01000  0.050   70000  1.800  26.64818  24.66589
# 68   2070  0.131999  0.01000  0.050   70000  1.800  26.72440  24.76522
#
#       PIB_VAL  PRELEV_REF  CONTRIB_REF   PIB_VOL
# 0    1578.330        26.9          2.0  2003.664
# 1    1622.313        27.6          2.0  2023.056
# 2    1696.108        27.9          2.0  2081.082
# 3    1762.048        27.9          2.0  2120.384
# 4    1846.021        28.0          2.1  2177.933
# ..        ...         ...          ...       ...
# 64   9250.220        28.7          1.1  3960.600
# 65   9492.102        28.7          1.0  3994.265
# 66   9740.309        28.7          1.0  4028.216
# 67   9993.023        28.7          1.0  4061.651
# 68  10249.245        28.7          1.0  4094.144
#
# [69 rows x 12 columns]

# %%
# Retail only real values
df_historical_data = grouped_dfs["group_0"]
df_historical_data = df_historical_data[df_historical_data['Annee'] < 2024]

# Remaining all scenario data
# Filter each DataFrame, then concatenate
filtered_dfs = [df[df['Annee'] >= 2024] for df in grouped_dfs.values()]
df_scenarios = pd.concat(filtered_dfs, ignore_index=True)

# %% [markdown]
# ## Include scenarios?

# %%
include_scenarios = True

if include_scenarios:
    # If you want all unique vales (real data + all scenarions), concatenate `df_historical_data` and `df_scenarios`
    df = pd.concat([df_historical_data, df_scenarios], ignore_index=True)
else:
    df = df_historical_data.copy()

# %%
print(df.head())
print(df.tail())
# Out:
#    Annee     D_PIB     PROD    CHO      MI    FEC  ESP_F  ESP_H   PIB_VAL  \
# 0   2002  0.117761  0.02786  0.079   97000  1.881   21.4   17.1  1578.330
# 1   2003  0.118774  0.00614  0.085  102000  1.891   21.3   17.1  1622.313
# 2   2004  0.119571  0.01315  0.089  105128  1.915   22.1   17.7  1696.108
# 3   2005  0.121331  0.00955  0.089   92192  1.938   22.0   17.7  1762.048
# 4   2006  0.121535  0.02648  0.088  112141  1.997   22.4   18.0  1846.021
#
#    PRELEV_REF  CONTRIB_REF   PIB_VOL
# 0        26.9          2.0  2003.664
# 1        27.6          2.0  2023.056
# 2        27.9          2.0  2081.082
# 3        27.9          2.0  2120.384
# 4        28.0          2.1  2177.933
#      Annee     D_PIB  PROD   CHO     MI  FEC     ESP_F     ESP_H    PIB_VAL  \
# 393   2066  0.131398  0.01  0.05  70000  1.8  23.99277  21.93565   9250.220
# 394   2067  0.131499  0.01  0.05  70000  1.8  24.02340  22.00315   9492.102
# 395   2068  0.131601  0.01  0.05  70000  1.8  24.05405  22.07035   9740.309
# 396   2069  0.131750  0.01  0.05  70000  1.8  24.08470  22.13728   9993.023
# 397   2070  0.131999  0.01  0.05  70000  1.8  24.11537  22.20391  10249.245
#
#      PRELEV_REF  CONTRIB_REF   PIB_VOL
# 393        28.7          1.1  3960.600
# 394        28.7          1.0  3994.265
# 395        28.7          1.0  4028.216
# 396        28.7          1.0  4061.651
# 397        28.7          1.0  4094.144

# %%
from pension_model.glm_wrapper import analyze_target_distribution, create_glm_recommendations

target_analysis = analyze_target_distribution(df=df, target_col='D_PIB')
print('Recommended GLM:')
create_glm_recommendations(target_analysis)
# Out:
# Recommended GLM:
# ['GLM_Gaussian_Log', 'GLM_Gamma_Log']

# %%
from pension_model.glm_wrapper import create_glm_recommendations

create_glm_recommendations(target_analysis)
# Out:
# ['GLM_Gaussian_Log', 'GLM_Gamma_Log']

# %% [markdown]
# ---

# %% [markdown]
# # Instantiate the model predictor

# %%
# Instantiate the predictor object with the target column
predictor = TimeSeriesPredictor(
    target_col='D_PIB', 
    lag_periods=[],
    rollign_windows=[],
    model_dir='../models/',
)

# %%
# Step 1: Load and explore data
df = predictor.load_and_explore_data(df)
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Loading and exploring data...
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Data loaded: 398 rows, 12 columns
# INFO:pension_model.predictor: Data loaded: 398 rows, 12 columns
# INFO:pension_model.predictor: Memory usage: 0.04 MB
# INFO:pension_model.predictor: ✓ No missing values detected
# INFO:pension_model.predictor: Data types:
# Annee            int64
# D_PIB          float64
# PROD           float64
# CHO            float64
# MI               int64
# FEC            float64
# ESP_F          float64
# ESP_H          float64
# PIB_VAL        float64
# PRELEV_REF     float64
# CONTRIB_REF    float64
# PIB_VOL        float64
# dtype: object
# INFO:pension_model.predictor: Target variable (D_PIB) statistics:
# count    398.000000
# mean       0.135282
# std        0.004921
# min        0.117761
# 25%        0.132409
# 50%        0.136231
# 75%        0.138154
# max        0.148541
# Name: D_PIB, dtype: float64
# INFO:pension_model.predictor: Potential outliers in target: 11 (2.8%)

# %% [markdown]
# ## Data visualization

# %%
# Step 2: Visualize data
correlation_matrix = predictor.visualize_data()
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor:Data visualization and pattern analysis...
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Carried out data visualization and returning correlation matrix.

# %%
correlation_matrix
# Out:
#                 D_PIB      PROD       CHO        MI       FEC     ESP_F  \
# D_PIB        1.000000 -0.507095  0.008838 -0.277427 -0.147255 -0.104555
# PROD        -0.507095  1.000000 -0.198469 -0.124735 -0.040050  0.094897
# CHO          0.008838 -0.198469  1.000000  0.174055  0.751548 -0.461851
# MI          -0.277427 -0.124735  0.174055  1.000000 -0.011415 -0.097077
# FEC         -0.147255 -0.040050  0.751548 -0.011415  1.000000 -0.333472
# ESP_F       -0.104555  0.094897 -0.461851 -0.097077 -0.333472  1.000000
# ESP_H       -0.129930  0.113337 -0.532904 -0.107899 -0.371770  0.975573
# PIB_VAL     -0.315483  0.197824 -0.511013 -0.098274 -0.327179  0.751834
# PRELEV_REF   0.418605 -0.216255  0.358712  0.112094 -0.028132 -0.542618
# CONTRIB_REF  0.220700 -0.131010  0.539909  0.097061  0.313504 -0.739529
# PIB_VOL     -0.403342  0.310648 -0.609049 -0.115302 -0.415167  0.720530
#
#                 ESP_H   PIB_VAL  PRELEV_REF  CONTRIB_REF   PIB_VOL
# D_PIB       -0.129930 -0.315483    0.418605     0.220700 -0.403342
# PROD         0.113337  0.197824   -0.216255    -0.131010  0.310648
# CHO         -0.532904 -0.511013    0.358712     0.539909 -0.609049
# MI          -0.107899 -0.098274    0.112094     0.097061 -0.115302
# FEC         -0.371770 -0.327179   -0.028132     0.313504 -0.415167
# ESP_F        0.975573  0.751834   -0.542618    -0.739529  0.720530
# ESP_H        1.000000  0.861539   -0.654131    -0.863966  0.828914
# PIB_VAL      0.861539  1.000000   -0.766306    -0.950731  0.963395
# PRELEV_REF  -0.654131 -0.766306    1.000000     0.843382 -0.700725
# CONTRIB_REF -0.863966 -0.950731    0.843382     1.000000 -0.907404
# PIB_VOL      0.828914  0.963395   -0.700725    -0.907404  1.000000

# %% [markdown]
# ## Perform statistical stets on normality and stationarity

# %%
# Step 3: Statistical tests
predictor.statistical_tests()
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Perform statistical tests and verify assumptions...
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Normality tests:
# INFO:pension_model.predictor: Jarque-Bera Test: statistic=34.6043, p-value=0.0000
# INFO:pension_model.predictor: Shapiro-Wilk Test: statistic=0.9537, p-value=0.0000
# INFO:pension_model.predictor: ⚠ Data may not be normally distributed
# INFO:pension_model.predictor: Stationary tests:
# INFO:pension_model.predictor: Augmented Dickey-Fuller Test:
# INFO:pension_model.predictor:    ADF Statistic: -4.1368
# INFO:pension_model.predictor:    p-value: 0.0008
# INFO:pension_model.predictor:    Critical Values: {'1%': np.float64(-3.4469295619737665), '5%': np.float64(-2.8688478565083417), '10%': np.float64(-2.570662885558566)}
# INFO:pension_model.predictor: ✓ Series is stationary (ADF test)

# %% [markdown]
# ## Perform feature engineering (to be improved)

# %%
# Step 4: Feature engineering
X, y = predictor.feature_engineering()
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Feature engineering and selection
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Original features: 10
# INFO:pension_model.predictor: Feature names: ['PROD', 'CHO', 'MI', 'FEC', 'ESP_F', 'ESP_H', 'PIB_VAL', 'PRELEV_REF', 'CONTRIB_REF', 'PIB_VOL']
# INFO:pension_model.predictor: Creating lag features...
# INFO:pension_model.predictor: Lag periods: [1, 2]
# INFO:pension_model.predictor: Created 20 lag features
# INFO:pension_model.predictor: Creating rolling window features...
# INFO:pension_model.predictor: Rolling windows: [9, 18]
# INFO:pension_model.predictor: Created 20 rolling window features
# INFO:pension_model.predictor: Removed 17 rows due to NaN values from feature engineering
# INFO:pension_model.predictor: Features after engineering: 50
# INFO:pension_model.predictor: Samples after cleaning: 381
# INFO:pension_model.predictor: Applying feature selection: selecting 20 out of 50 features
# INFO:pension_model.predictor: Selected features (20): ['PROD', 'PIB_VAL', 'PRELEV_REF', 'CONTRIB_REF', 'PIB_VOL', 'PROD_lag_1', 'PROD_lag_2', 'MI_lag_1', 'PIB_VAL_lag_1', 'PIB_VAL_lag_2', 'PRELEV_REF_lag_1', 'PIB_VOL_lag_1', 'PIB_VOL_lag_2', 'PROD_roll_mean_9', 'PROD_roll_mean_18', 'MI_roll_mean_9', 'MI_roll_mean_18', 'PIB_VAL_roll_mean_9', 'PIB_VOL_roll_mean_9', 'PIB_VOL_roll_mean_18']
# INFO:pension_model.predictor: Feature engineering completed:
# INFO:pension_model.predictor:   - Created 40 new features
# INFO:pension_model.predictor:   - Selected 20 final features
# INFO:pension_model.predictor:   - Max lag period: 2

# %%
predictor.feature_names
# Out:
# Index(['PROD', 'PIB_VAL', 'PRELEV_REF', 'CONTRIB_REF', 'PIB_VOL', 'PROD_lag_1',
#        'PROD_lag_2', 'MI_lag_1', 'PIB_VAL_lag_1', 'PIB_VAL_lag_2',
#        'PRELEV_REF_lag_1', 'PIB_VOL_lag_1', 'PIB_VOL_lag_2',
#        'PROD_roll_mean_9', 'PROD_roll_mean_18', 'MI_roll_mean_9',
#        'MI_roll_mean_18', 'PIB_VAL_roll_mean_9', 'PIB_VOL_roll_mean_9',
#        'PIB_VOL_roll_mean_18'],
#       dtype='object')

# %%
# Step 5: Prepare data
X_scaled, y = predictor.prepare_data_for_modeling()
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Data preparation and scaling...
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Applied RobustScaler to features
# INFO:pension_model.predictor: Set up TimeSeriesSplit with 5 folds
# INFO:pension_model.predictor: Data preparation completed. Features: 20

# %% [markdown]
# ## Train different models

# %%
# Step 6: Train models
results = predictor.train_models()
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Model training and comparison
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Training Random Forest...
# INFO:pension_model.predictor:    Performing hyperparameter tuning...
# INFO:pension_model.predictor:    Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}
# INFO:pension_model.predictor:    Performing cross-validation...
# INFO:pension_model.predictor:    CV RMSE: 0.003249 (+/- 0.002952)
# INFO:pension_model.predictor: Training GLM_Gamma_Log...
# INFO:pension_model.predictor:    Performing hyperparameter tuning...
# INFO:pension_model.predictor:    Best parameters: {'alpha': 0.0, 'fit_intercept': True}
# INFO:pension_model.predictor:    Performing cross-validation...
# INFO:pension_model.predictor:    CV RMSE: 0.001953 (+/- 0.002315)
# INFO:pension_model.predictor: Training GLM_Gaussian_Log...
# INFO:pension_model.predictor:    Performing hyperparameter tuning...
# INFO:pension_model.predictor:    Best parameters: {'alpha': 0.0, 'fit_intercept': True}
# INFO:pension_model.predictor:    Performing cross-validation...
# INFO:pension_model.predictor:    CV RMSE: 0.001950 (+/- 0.002339)
# INFO:pension_model.predictor: Training GLM_Tweedie_1.5...
# INFO:pension_model.predictor:    Performing hyperparameter tuning...
# INFO:pension_model.predictor:    Best parameters: {'alpha': 0.0, 'fit_intercept': True}
# INFO:pension_model.predictor:    Performing cross-validation...
# INFO:pension_model.predictor:    CV RMSE: 0.002012 (+/- 0.002202)
# INFO:pension_model.predictor: Training GLM_Tweedie_1.9...
# INFO:pension_model.predictor:    Performing hyperparameter tuning...
# INFO:pension_model.predictor:    Best parameters: {'alpha': 0.0, 'fit_intercept': True}
# INFO:pension_model.predictor:    Performing cross-validation...
# INFO:pension_model.predictor:    CV RMSE: 0.002012 (+/- 0.002202)
# INFO:pension_model.predictor:  🏆 Champion model: GLM_Gaussian_Log
# INFO:pension_model.predictor:   CV RMSE: 0.001950

# %% [markdown]
# ## Model evaluation

# %%
# Step 7: Evaluate best model
evaluation = predictor.evaluate_model()
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Model evaluation and diagnostics...
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Final Model Performance (GLM_Gaussian_Log):
# INFO:pension_model.predictor:    RMSE: 0.000944
# INFO:pension_model.predictor:    MAE:  0.000669
# INFO:pension_model.predictor:    R-squared:   0.957510

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Model comparison

# %%
# Step 8: Model comparison
comparison = predictor.model_comparison_summary()
# Out:
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Model comparison summary...
# INFO:pension_model.predictor:============================================================
# INFO:pension_model.predictor: Model performance ranking:
#            Model  CV_RMSE_Mean  CV_RMSE_Std
# GLM_Gaussian_Log      0.001950     0.001170
#    GLM_Gamma_Log      0.001953     0.001157
#  GLM_Tweedie_1.5      0.002012     0.001101
#  GLM_Tweedie_1.9      0.002012     0.001101
#    Random Forest      0.003249     0.001476

# %% [markdown]
# ## Save best model

# %%
model_path = predictor.save_best_model("production_model_v1")
print(f" Model saved to: {model_path}")
# Out:
# INFO:pension_model.predictor: Model saved to ..\models\production_model_v1\model.pkl
# INFO:pension_model.predictor: Preprocessing pipeline saved to ..\models\production_model_v1\preprocessing_pipeline.pkl
# INFO:pension_model.predictor: Metadata saved to ..\models\production_model_v1\metadata.json
# INFO:pension_model.predictor: Complete model package saved to ..\models\production_model_v1
#  Model saved to: ..\models\production_model_v1

# %% [markdown]
# ---
# ---
